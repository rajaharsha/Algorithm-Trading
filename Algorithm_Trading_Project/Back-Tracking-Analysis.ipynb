# %% [markdown]
# ## Backtracking Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mcdon = get_pricing('MCD',
                    start_date = '2005-01-01',
                    end_date = '2017-02-01',
                    frequency='minute')

# %%
mcdon.head()
# Out:
#                            open_price    high     low  close_price    volume  \
# 2005-01-03 14:31:00+00:00         NaN     NaN     NaN          NaN       0.0
# 2005-01-03 14:32:00+00:00         NaN     NaN     NaN          NaN       0.0
# 2005-01-03 14:33:00+00:00      22.110  22.152  22.068       22.152  282600.0
# 2005-01-03 14:34:00+00:00      22.180  22.299  22.082       22.110   53400.0
# 2005-01-03 14:35:00+00:00      22.285  22.292  22.201       22.264   25100.0
#
#                                price
# 2005-01-03 14:31:00+00:00  22.438551
# 2005-01-03 14:32:00+00:00  22.438551
# 2005-01-03 14:33:00+00:00  22.152000
# 2005-01-03 14:34:00+00:00  22.110000
# 2005-01-03 14:35:00+00:00  22.264000

# %%
mcdon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1181880 entries, 2005-01-03 14:31:00+00:00 to 2017-02-01 21:00:00+00:00
# Data columns (total 6 columns):
# open_price     1180952 non-null float64
# high           1180952 non-null float64
# low            1180952 non-null float64
# close_price    1180952 non-null float64
# volume         1181880 non-null float64
# price          1181880 non-null float64
# dtypes: float64(6)
# memory usage: 63.1 MB

# %%
mcdon['close_price'].plot()

# %%
mcdon_eq_info = symbols('MCD')
mcdon_eq_info.to_dict()
# Out:
# {'asset_name': u'MCDONALDS CORP',
#  'auto_close_date': Timestamp('2018-02-23 00:00:00+0000', tz='UTC'),
#  'end_date': Timestamp('2018-02-20 00:00:00+0000', tz='UTC'),
#  'exchange': u'NYSE',
#  'exchange_full': u'NEW YORK STOCK EXCHANGE',
#  'first_traded': None,
#  'sid': 4707,
#  'start_date': Timestamp('2002-01-01 00:00:00+0000', tz='UTC'),
#  'symbol': u'MCD'}

# %%
backtest_results = get_backtest('5aabac6f9bddab425cb8a678')
# Out:
# 100% Time: 0:00:01|###########################################################|

# %%
backtest_results.create_full_tear_sheet()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-02-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>13</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-24.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-27.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>37.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.56</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.46</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-53.3%</td>
#     </tr>
#     <tr>
# ...

# %%
backtest_results = get_backtest('5aabeeb4bb945e41ee803790')
# Out:
# 100% Time: 0:00:01|###########################################################|

# %%
backtest_results.create_full_tear_sheet()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-02-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>13</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-5.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-5.6%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.11</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.20</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-25.2%</td>
#     </tr>
#     <tr>
# ...
